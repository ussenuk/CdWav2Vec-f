# %% [markdown]
# ## train the LM

# %%
import sys

# %%
# !{sys.executable} -m pip install https://github.com/kpu/kenlm/archive/master.zip 
# !{sys.executable} -m pip install pyctcdecode==0.3.0
# !{sys.executable} -m pip install datasets==2.0.0
# !{sys.executable} -m pip install transformers==4.18.0

# %%
# !{sys.executable} -m pip install ipywidgets

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !sudo apt install build-essential cmake libboost-system-dev libboost-thread-dev libboost-program-options-dev libboost-test-dev libeigen3-dev zlib1g-dev libbz2-dev liblzma-dev

# %%
# !wget -O - https://kheafield.com/code/kenlm.tar.gz | tar xz

# %%
# !mkdir kenlm/build && cd kenlm/build && cmake .. && make -j2

# %%
# !ls kenlm/build/bin

# %%
target_lang="sv"  # change to your target lang

# %%
from datasets import load_dataset

username = "hf-test"  # change to your username

dataset = load_dataset(f"{username}/{target_lang}_corpora_parliament_processed", split="train")

with open("text.txt", "w") as file:
  file.write(" ".join(dataset["text"]))

# %%
# !kenlm/build/bin/lmplz -o 5 <"text.txt" > "5gram.arpa"

# %%
# !head -20 5gram.arpa

# %%
with open("5gram.arpa", "r") as read_file, open("5gram_correct.arpa", "w") as write_file:
  has_added_eos = False
  for line in read_file:
    if not has_added_eos and "ngram 1=" in line:
      count=line.strip().split("=")[-1]
      write_file.write(line.replace(f"{count}", f"{int(count)+1}"))
    elif not has_added_eos and "<s>" in line:
      write_file.write(line)
      write_file.write(line.replace("<s>", "</s>"))
      has_added_eos = True
    else:
      write_file.write(line)

# %%
# !head -20 5gram_correct.arpa

# %%
from transformers import AutoProcessor

processor = AutoProcessor.from_pretrained("/home/ubuntu/xlsr-3bb")

# %%
vocab_dict = processor.tokenizer.get_vocab()
sorted_vocab_dict = {k.lower(): v for k, v in sorted(vocab_dict.items(), key=lambda item: item[1])}

# %%
sorted_vocab_dict

# %%
#from pyctcdecode import build_ctcdecoder


#labels = [
#    "s","b","l","u","ç","i","o","f","d","k","ɔ","t","r","w","j","p","x","v","c","z",
#    "h","q","y","m","|","e","n","ε","a","g","[UNK]","[PAD]","<s>","</s>"
#]
    
# prepare decoder and decode logits via shallow fusion
#decoder = build_ctcdecoder(
#    labels,
#    kenlm_model_path="5gram_correct.arpa",  # either .arpa or .bin file
#)

# %%
from pyctcdecode import build_ctcdecoder

decoder = build_ctcdecoder(
    labels=list(sorted_vocab_dict.keys()),
    kenlm_model_path="5gram_correct.arpa",
)

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer.from_pretrained("/home/ubuntu/xlsr-3bb", eos_token=None, bos_token=None)

# %%
from transformers import Wav2Vec2ProcessorWithLM

processor_with_lm = Wav2Vec2ProcessorWithLM(
    feature_extractor=processor.feature_extractor,
    tokenizer=processor.tokenizer,
    decoder=decoder
)

# %%
from huggingface_hub import Repository

repo = Repository(local_dir="xlsr-lingala2", clone_from="Ussen/wav2vec2-large-xlsr-lingala")

# %%
processor_with_lm.save_pretrained("xlsr-lingala2")

# %%
#use the terminal
# !kenlm/build/bin/build_binary xlsr-lingala2/language_model/5gram_correct.arpa xlsr-lingala2/language_model/5gram.bin

# %%
# !rm xlsr-lingala2/language_model/5gram_correct.arpa && tree -h xlsr-lingala2/

# %% [markdown]
# ## push to hub

# %%
# !git clone https://huggingface.co/Ussen/xlsr-lingala2

# %%
# this code worked with the following torch setup
# !{sys.executable} -m pip install torch==1.12.0+cu116 torchvision==0.13.0+cu116 torchaudio==0.12.0 --extra-index-url https://download.pytorch.org/whl/cu116

# %%
from transformers import Wav2Vec2ProcessorWithLM, Wav2Vec2ForCTC

processor = Wav2Vec2ProcessorWithLM.from_pretrained("/home/ubuntu/LM/xlsr-lingala2")
model = Wav2Vec2ForCTC.from_pretrained("/home/ubuntu/LM/xlsr-lingala2")

# %%
from transformers import AutoProcessor

processor1 = AutoProcessor.from_pretrained("/home/ubuntu/xlsr-3bb")
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# ## load the test set

# %%
import sys

# %%
# !{sys.executable} -m pip install torchaudio
# !{sys.executable} -m pip install librosa
# !{sys.executable} -m pip install jiwer
# !{sys.executable} -m pip install -qqq evaluate==0.2.2

# %%
import os
#Connect to Gdrive to store model checkpoints
#from google.colab import drive
#drive.mount('/content/drive',force_remount=True)

# %%
import numpy as np
import zipfile
import csv

# %%
import zipfile
zip_ref = zipfile.ZipFile("/home/ubuntu/LM/LingalaAudio-20221111T081505Z-001.zip", 'r')
zip_ref.extractall("/home/ubuntu/LM")
zip_ref.close()

# %%
with open('/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/train.csv', newline='',encoding='UTF-8') as f:
      reader = csv.reader(f)
      data = list(reader)
      train_data = [data[i] for i in range(len(data)) if i!=0]

with open('/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test.csv', newline='',encoding='UTF-8') as f:
      reader = csv.reader(f)
      data = list(reader)
      t_data = [data[i] for i in range(len(data)) if i!=0]

# %%
print(train_data)
# Out:
# [['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_0.wav', '2.404875', 'tala ndenge bakei kobatama likolo na plafond'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_1.wav', '2.404875', 'omoni oyɔ eza kaka baattaque'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_2.wav', '2.404875', 'lokola bakoki ngai na mosuni te namoni balingi sikoyɔ bameka na molili'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_3.wav', '2.404875', 'boyebaka pe bisika na kotaka te'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_4.wav', '2.404875', 'lobi nakobengisa bango nyɔnso awa'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_5.wav', '2.404875', 'baya tomanyɔmala malamumalamu ndenge nini nakobimisa likanisi na ngai wana na onu'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_6.wav', '2.404875', 'nayebi ete bango nyɔnso bakokamwa'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_7.wav', '2.404875', 'oyɔ ayaki na baboul na ye wana ya bana mike'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_8.wav', '2.404875', 'ye moko mpenza akomona ete azalaki kaka bolole'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_9.wav', '2.404875', 'bato mibimba bakolo mpenza kasi balingi kaka kosala makambo lokola bana mike'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_10.wav', '2.404875', 'bafrancais na bango ezanga tina'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_11.wav', '2.404875', 'toya kokotisa ata mwa masuwa na mayi'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_12.wav', '2.404875', 'yɔka bango kuna na badiscours milayi milayi na bafrancais ezanga tina'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_13.wav', '2.404875', 'makambo wana nyɔnso esengeli tolobela yango na likita ya ntɔngɔ ya lεlɔ'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_14.wav', '2.404875', 'mboka monene boye pe kino lεlɔ tobikaka kaka na kobangabanga'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_15.wav', '2.404875', 'nayebisa bango ete nalingi nakoma kosala masolo misusu na bachinois'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_16.wav', '2.404875', 'bango nyɔnso bayei kotelemela ngai lokola nabomi mɔtɔ'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_17.wav', '2.404875', 'tata mokonzi omoni soki osali bongo bato wana bakomona ete yɔ okomi kosala makambo ndenge bango balingi te'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_18.wav', '2.404875', 'sukasuka bakoluka kaka balongola yɔ na ebonga'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_19.wav', '2.404875', 'baza mpenza maboma bato oyɔ'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_20.wav', '2.404875', 'donc ata mwa susi mokε ya mboka ezalaka te'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_21.wav', '2.404875', 'lεlɔ oyɔ tala ndenge makambo kili kili esalami'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_22.wav', '2.404875', 'bango wana bakomi kobetela ngai mabɔkɔ pe koloba kutu ete ngai nde tata ya kimpwanza ya nkita ya mboka'], ['/home/ubuntu/organised_recording/data/train/wav/edimon/221010-123027_lin_359_elicit_23.wav', '2.404875', 'nabukanaki nakoseka mpenza tango nayokaki ye koloba bongo'], ['/home/ubuntu/organised ...

# %%
#Get valid indices
import random
random.seed(42) #this seed was used specifically to compare with Okwugbe model



v = 300 #200 samples for valid. Change as you want
test_list = [i for i in range(len(t_data))]
valid_indices = random.choices(test_list, k=v)


test_data = [t_data[i] for i in range(len(t_data)) if i not in valid_indices]
valid_data = [t_data[i] for i in range(len(t_data)) if i in valid_indices]

# %%
def create_json_file(d):
  utterance = d[2]
  wav_path =d[0]
  wav_path = wav_path.replace("/home/ubuntu/organised_recording","/home/ubuntu/LM/LingalaAudio/pyLingala-master")
  return {
      "path": wav_path,
      "sentence": utterance
  }

train_json = [create_json_file(i) for i in train_data]
test_json = [create_json_file(i) for i in test_data]
valid_json = [create_json_file(i) for i in valid_data]

# %%
import os

# %%
#Make folder in GDrive to store files
#train_path = '/content/drive/MyDrive/lingala_xlsr2/train'
#test_path = '/content/drive/MyDrive/lingala_xlsr2/test'
#valid_path = '/content/drive/MyDrive/lingala_xlsr2/valid'

train_path = '/home/ubuntu/LM/lingala_xlsr/train'
test_path = '/home/ubuntu/LM/lingala_xlsr/test'
valid_path = '/home/ubuntu/LM/lingala_xlsr/valid'

if not os.path.isdir(train_path):
  print("Creating paths")
  os.makedirs(train_path)
  os.makedirs(test_path)
  os.makedirs(valid_path)
# Out:
# Creating paths

# %%
import json
#for train
for i, sample in enumerate(train_json):
  file_path = os.path.join(train_path,'train_lingala_{}.json'.format(i))
  with open(file_path, 'w') as outfile:
    json.dump(sample, outfile)

#for test
for i, sample in enumerate(test_json):
  file_path = os.path.join(test_path,'test_lingala_{}.json'.format(i))
  with open(file_path, 'w') as outfile:
    json.dump(sample, outfile)

#for valid
for i, sample in enumerate(valid_json):
  file_path = os.path.join(valid_path,'valid_lingala_{}.json'.format(i))
  with open(file_path, 'w') as outfile:
    json.dump(sample, outfile)

# %%
#run the second time after the error
from datasets import load_dataset, load_metric

#for train
for root, dirs, files in os.walk(train_path):
  lingala_train = load_dataset("json", data_files=[os.path.join(root,i) for i in files],split="train")

#for test
for root, dirs, files in os.walk(test_path):
  lingala_test = load_dataset("json", data_files=[os.path.join(root,i) for i in files],split="train")

#for valid
for root, dirs, files in os.walk(valid_path):
  lingala_valid = load_dataset("json", data_files=[os.path.join(root,i) for i in files],split="train")
# Out:
# Resolving data files:   0%|          | 0/2465 [00:00<?, ?it/s]
# Using custom data configuration default-6a98a2e1fcdab904
# Downloading and preparing dataset json/default to /home/ubuntu/.cache/huggingface/datasets/json/default-6a98a2e1fcdab904/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /home/ubuntu/.cache/huggingface/datasets/json/default-6a98a2e1fcdab904/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
# Resolving data files:   0%|          | 0/180 [00:00<?, ?it/s]
# Using custom data configuration default-23c758c876f9dc6b
# Downloading and preparing dataset json/default to /home/ubuntu/.cache/huggingface/datasets/json/default-23c758c876f9dc6b/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /home/ubuntu/.cache/huggingface/datasets/json/default-23c758c876f9dc6b/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
# Resolving data files:   0%|          | 0/204 [00:00<?, ?it/s]
# Using custom data configuration default-973068965cfcd3dc
# Downloading and preparing dataset json/default to /home/ubuntu/.cache/huggingface/datasets/json/default-973068965cfcd3dc/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /home/ubuntu/.cache/huggingface/datasets/json/default-973068965cfcd3dc/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.

# %%
lingala_test
# Out:
# Dataset({
#     features: ['path', 'sentence'],
#     num_rows: 180
# })

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    print(len(dataset))
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(lingala_test, num_examples=20)
# Out:
# 180
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>path</th>
#       <th>sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/joe/220716-083749_lin_9f7_elicit_47.wav</td>
#       <td>amoni elongi ya mama na bango akufa motema na ye ekiti</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/garcongina/220719-141705_lin_9f7_elicit_134.wav</td>
#       <td>soki kaka polele pawu</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/yan2/220717-135652_lin_9f7_elicit_94.wav</td>
#       <td>nyɔnso wana ezosalama tshotsho kodiongo pe azoyeba te</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/v/220716-105601_lin_9f7_elicit_90.wav</td>
#       <td>afandi mwa kimya azongisi mokongo na nsima</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/garcongina/220719-141705_lin_9f7_elicit_111.wav</td>
#       <td>akobi na kolobaka ete soki bobwakisi ngai bokotiya nani</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/yan2/220717-135652_lin_9f7_elicit_82.wav</td>
#       <td>po ndelo oyɔ mwananyoka abongisaki ndako wana oza na likanisi te</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/deborah/220718-132354_lin_9f7_elicit_9.wav</td>
#       <td>mawa esunda pongi eyingela olongwa susi na ngai</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/garcongina/220719-141705_lin_9f7_elicit_124.wav</td>
#       <td>bato bazalaki kokεngεla ye basutuka</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/garcongina/220719-141705_lin_9f7_elicit_113.wav</td>
#       <td>na ndenge ya respect petit tangu akoti na esika bakulutu bazali ezosenga mwa nsamba ekita</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/v/220716-105601_lin_9f7_elicit_97.wav</td>
#       <td>yɔka yɔ masolo ozalaka na yango</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/urbain/220716-130438_lin_9f7_elicit_51.wav</td>
#       <td>atali esika motuka etelemaki</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/joe/220716-082553_lin_9f7_elicit_37.wav</td>
#       <td>ayebi pe malamu tina nini azali kobenga ye</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/gina/220719-141705_lin_9f7_elicit_71.wav</td>
#       <td>yɔ okanisi toyebi yɔ te</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/urbain/220716-131602_lin_9f7_elicit_87.wav</td>
#       <td>zonga na ebele ya mosolo na yɔ osala elambo na misuni ya bato oliaka</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/deborah/220718-132354_lin_9f7_elicit_17.wav</td>
#       <td>naweli bokonzi na kisasa nazwi tango te ya kobatela yɔ</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/yan2/220717-135652_lin_9f7_elicit_86.wav</td>
#       <td>na tango wana muji asombi mapango misato na kinshasa</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/yan/220717-112613_lin_9f7_elicit_7.wav</td>
#       <td>mwananyoka apusani pεnε na ye azwi kopo ya masanga amelisi excellence</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/yan2/220717-135652_lin_9f7_elicit_84.wav</td>
#       <td>kimya oyɔ ya ye</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/joe/220716-082553_lin_9f7_elicit_41.wav</td>
#       <td>mwa mayi moko ezalaki wana</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/garcongina/220719-141705_lin_9f7_elicit_112.wav</td>
#       <td>boki nasombi ezali kaka luzitu bino bozali na vieux na ngai bosimbi masolo</td>
#     </tr>
#   </tbody>
# </table>

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\�]'

def remove_special_characters(batch):
    batch["sentence"] = re.sub(chars_to_ignore_regex, '', batch["sentence"]).lower() + " "
    return batch

# %%
lingala_train = lingala_train.map(remove_special_characters)
lingala_test = lingala_test.map(remove_special_characters)
lingala_valid = lingala_valid.map(remove_special_characters)
# Out:
# Parameter 'function'=<function remove_special_characters at 0x7fea01cdb640> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
#   0%|          | 0/2465 [00:00<?, ?ex/s]
#   0%|          | 0/180 [00:00<?, ?ex/s]
#   0%|          | 0/204 [00:00<?, ?ex/s]

# %%
show_random_elements(lingala_train.remove_columns(["path"]))
# Out:
# 2465
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>fkm azwaki visa ya ba touristes mpo na sanza moko</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>likofi na libumu</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>akomaki mwa mɔtɔ ye nde mɔtɔ akomaki kosukola basani</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>mbote tata mokonzi</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>djef azalaki mokongo mpe marielouise azala moluba</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ntango wana miraesa atindi moninga na ye moko akεndε koyebisa baboti ya fkm</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>fkm ayɔki nzutu</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>ngai nde mokonzi ya ekolo</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>na mboka eyindi pe na mbala moko</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>moro azongiseli ye ete  ngai natekaka na depot ya mere moko na le marche</td>
#     </tr>
#   </tbody>
# </table>

# %%
#def extract_all_chars(batch):
#  all_text = " ".join(batch["sentence"])
#  vocab = list(set(all_text))
#  return {"vocab": [vocab], "all_text": [all_text]}

# %%
#vocab_train = lingala_train.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=lingala_train.column_names)
#vocab_test = lingala_test.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=lingala_test.column_names)
#vocab_valid = lingala_valid.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=lingala_valid.column_names)

# %%
#vocab_list = list(set(vocab_train["vocab"][0]) | set(vocab_test["vocab"][0]) | set(vocab_valid["vocab"][0]))

# %%
#vocab_dict = {v: k for k, v in enumerate(vocab_list)}
#vocab_dict

# %%
#vocab_dict["|"] = vocab_dict[" "]
#del vocab_dict[" "]

# %%
#vocab_dict["[UNK]"] = len(vocab_dict)
#vocab_dict["[PAD]"] = len(vocab_dict)
#len(vocab_dict)

# %%
#from transformers import Wav2Vec2ProcessorWithLM

#processor = Wav2Vec2ProcessorWithLM.from_pretrained("/content/xlsr-lingala1")
#model = Wav2Vec2ForCTC.from_pretrained("/content/xlsr-lingala1")

# %%
import torchaudio

def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    batch["speech"] = speech_array[0].numpy()
    batch["sampling_rate"] = sampling_rate
    batch["target_text"] = batch["sentence"]
    return batch

# %%
lingala_train = lingala_train.map(speech_file_to_array_fn, remove_columns=lingala_train.column_names)
lingala_test = lingala_test.map(speech_file_to_array_fn, remove_columns=lingala_test.column_names)
lingala_valid = lingala_valid.map(speech_file_to_array_fn, remove_columns=lingala_valid.column_names)
# Out:
#   0%|          | 0/2465 [00:00<?, ?ex/s]
#   0%|          | 0/180 [00:00<?, ?ex/s]
#   0%|          | 0/204 [00:00<?, ?ex/s]

# %%
def prepare_dataset(batch):
    # check that all files have the correct sampling rate
    assert (
        len(set(batch["sampling_rate"])) == 1
    ), f"Make sure all inputs have the same sampling rate of {processor.feature_extractor.sampling_rate}."

    batch["input_values"] = processor(batch["speech"], sampling_rate=batch["sampling_rate"][0]).input_values
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["target_text"]).input_ids
    return batch

# %%
lingala_train = lingala_train.map(prepare_dataset, remove_columns=lingala_train.column_names, batch_size=4, num_proc=2, batched=True)
lingala_test = lingala_test.map(prepare_dataset, remove_columns=lingala_test.column_names, batch_size=4, num_proc=2, batched=True)
lingala_valid = lingala_valid.map(prepare_dataset, remove_columns=lingala_valid.column_names, batch_size=4, num_proc=2, batched=True)
# Out:
# #0:   0%|          | 0/309 [00:00<?, ?ba/s]
# #1:   0%|          | 0/308 [00:00<?, ?ba/s]
# /home/ubuntu/pyenv/lib/python3.10/site-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /home/ubuntu/pyenv/lib/python3.10/site-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# #0:   0%|          | 0/23 [00:00<?, ?ba/s]
# #1:   0%|          | 0/23 [00:00<?, ?ba/s]
# /home/ubuntu/pyenv/lib/python3.10/site-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /home/ubuntu/pyenv/lib/python3.10/site-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# #0:   0%|          | 0/26 [00:00<?, ?ba/s]
# #1:   0%|          | 0/26 [00:00<?, ?ba/s]
# /home/ubuntu/pyenv/lib/python3.10/site-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)
# /home/ubuntu/pyenv/lib/python3.10/site-packages/transformers/feature_extraction_utils.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = as_tensor(value)

# %% [markdown]
# ## test a single file

# %%
import librosa
import torchaudio

# %%
# load the audio data (use your own wav file here!)
input_audio, sr = librosa.load('/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/deborah/220718-132354_lin_9f7_elicit_11.wav', sr=16000)

# %%
# tokenize
input_values = processor(input_audio, return_tensors="pt")
# Out:
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.

# %%
# retrieve logits
import torch

with torch.no_grad():
  logits = model(**input_values).logits

# %%
# decode using n-gram
transcription = processor.batch_decode(logits.numpy()).text

# %%
transcription[0].lower()
# Out:
# 'ekomelinga boni'

# %%
import IPython.display as ipd

audio_sample = "/home/ubuntu/LM/LingalaAudio/pyLingala-master/data/test/wav/deborah/220718-132354_lin_9f7_elicit_11.wav"
ipd.Audio(data=audio_sample, autoplay=True, rate=audio_sample)

import torch
import torchaudio
import soundfile

waveform, sampling_rate = soundfile.read( audio_sample )

features = processor(waveform, sampling_rate=16000, return_tensors="pt")

#input_values = features.input_values
#attention_mask = features.attention_mask

with torch.no_grad():
  logits = model(**features).logits

transcription = processor.batch_decode(logits.numpy()).text
transcription[0].lower()

# %%
import io
import os
import math
import torch
import warnings
from tqdm.notebook import tqdm

# %%
#input_dict = processor(lingala_test["input_values"][50],sampling_rate=16000, return_tensors="pt", padding=True)

#logits = model(input_dict.input_values).logits

#pred_ids = torch.argmax(logits, dim=-1)[0]

# %%
#logits.shape

# %%
#" ".join(sorted(processor.tokenizer.get_vocab()))

# %%
#transcription = processor.batch_decode(logits.numpy()).text
#transcription[0].lower()

# %%
#print("Prediction:")
#print(processor.decode(pred_ids))

#print(processor.decode(lingala_test["input_values"][0]))

#print("\nReference:")
#print(common_voice_test_transcription["sentence"][0].lower())
#print(processor.decode(lingala_test["labels"][50]))
#print("Target text:", lingala_test[0]["target_text"])

# %% [markdown]
# ## test on multiple files

# %%
from tqdm import tqdm

# %%
final_pred = []
for i in tqdm(range(lingala_test.shape[0])):    
    input_dict = processor(lingala_test["input_values"][i],sampling_rate=16000, return_tensors="pt", padding=True)
    with torch.no_grad():
        logits = model(input_dict.input_values).logits

    #pred_ids = torch.argmax(logits, dim=-1)[0]
    #prediction = processor.decode(pred_ids)
    prediction = processor.batch_decode(logits.numpy()).text
    final_pred.append(prediction)
# Out:
# 100%|██████████| 180/180 [28:09<00:00,  9.38s/it]

# %%
final_pred
# Out:
# [['moyi ezalaki kongala makasi'],
#  ['yango nde lopango moudiasombaki na mbɔngɔ thotjo ayebiki'],
#  ['ezali kala'],
#  ['aboyi kokεndε poto'],
#  ['alobi ozali mwana ya barumbu osilisi okeyi kaka bongo'],
#  ['tshotsho asepeli'],
#  ['heure wana kimbance que ezalaki mingi bamboka ya bakoko'],
#  ['mingala mike mike pe epayi basi oyɔ ya mpεmbεni bango basengaka na ndenge ya mokε te'],
#  ['kitoko elɔkɔ te'],
#  ['nyɔnso wana ezosalama tshotsho kodiongo mpe azoyebi te'],
#  ['yɔka yɔ masolo ozalaka nango'],
#  ['na nkoto mibale na zomi na sambo lopango ya suka etikalaki yango wana'],
#  ['nakokεndε na ye wapi soki balongoli ye'],
#  ['ata pe ozali mwana balumbo osala nini'],
#  ['afandaka lopango monene kaka ye moko'],
#  ['na kozala te mokolokooi kotelema'],
#  ['palabala na kikwiti batongi te'],
#  ['baye komona ete azalaki kolobela mopa oyɔ azalaki na katiya masedesi ya mwindu'],
#  ['tika koloba boye'],
#  ['tolangola mwa ce'],
#  ['bakola kobenga yɔ bonklian'],
#  ['mibali oyɔ nyɔkolaki pe obomaki bazali bandeko na ngai'],
#  ['bakozala kofuta mbɔngɔ na cunte na ye ya banki'],
#  ['lobi na yango excellence ayebi mbɔngɔ elengelamaki po na kobongisa balabala moko na engumbakiwiti'],
#  ['lokola mosesa ya nsɔni bakata ye wana abendi pekitipe afandi'],
#  ['tango asilisi koliya likanisi eyeli ye'],
#  ['kimya oyɔ ya ye'],
#  ['asimbi ye na loboko na makasi nyɔnso po atelema'],
#  ['bilɔkɔ ya kolia'],
#  ['azwi elongi atelemisi yango na lolendo ya kimpavita'],
#  ['lεlɔ bawumbu ekoma na yango liziba ya bosoto ezanga mbisi'],
#  ['oyɔ nalonaki nde na buki'],
#  ['na ndenge ya respe petit tango akoti na esika bakulutu bazali ezosenga mwasamba ye kita'],
#  ['tala ebemba mama na yɔ'],
#  ['nzoto ya mwasi ekomi eyinelo nakosolo te'],
#  ['akomi kaka koloba lisolo na litoyi ya makango na ye oyɔ babimaki na ye'],
#  ['kuna asombi pe lopango afandi masolo mpe ebongwani'],
#  ['mawa esunda pongi eyingela olongola souci na ngai'],
#  ['amoni elongi ya mama na bango akufa motema na ye ekiti'],
#  ['na mobulu wana mokumbi amonaki te ete libulu moko ya monene ezalaki na matakanelo ya bokasi'],
#  ['etellense mosusu mpe ayebi soki mbɔngɔ ya kotɔnga soki lopitalo asombi yango na un million'],
#  ['bino nde bapomba'],
#  ['atikali kuna elongi na kitalatala ntango molayi mpenza'],
#  ['tala ande kotele mana malεmbε'],
#  ['azongeli kaka komisionare oyɔ amemelaki ye masolo yango'],
#  ['tshotshoka diongo motema ekiti'],
#  ['ntango motema na ye sanduku etuni ye ebongo sikoyɔ nzela oyɔ ebongaki kotɔnga na kikwiti'],
#  ['mbala bana bokasi ooɔyɔ'],
#  ['wana pe mokonzi yango zoba lokola soki ndenge nini asepeli'],
#  ['bozosilisa batata bato bambɔgɔ na bango'],
#  ['mvula nyɔnso akoma koteka lopango moko'],
#  ['koloba ozali mwana ya barumbu ndako na biso ezalaki wapi'],
#  ['makanisi ezali kotambola ye mbango mbango'],
#  ['zonga na ebele ya masolo na yɔ osala elambo na misuni ya bato liaka'],
#  ['bakomi kokanisa ndenge bazalaki kokεndε kopotana na lisano ya ndembo na bana ya can hotraco'],
#  ['mwana moninga mawa te'],
#  ['ye moko amiyanoli esala nini'],
#  ['tozalaki kobeta na mpo na kolakisa makasi'],
#  ['oyɔ ya kolongola retroviseure alongoli retroviser oyɔ ya kolongola pinai alongoli pineis oyɔ ya kolongola parprise alongoli papris'],
#  ['nakese ya leta mbɔngɔ ezali kobima po na kobongisa banzela'],
#  ['tozobeta babale na butundeko'],
#  ['ameli mayεlε pe bwanya na ye'],
#  ['bato bayei ebele esika yango mɔtɔ akoki pe kosunga bango ezali te'],
#  ['na ntango wana muji asombi mapango misato na kinshasa'],
#  ['ata nsɔni te obengi ngai mwasi na yɔ'],
#  ['atunni muji balobi na ye ete ayaki kaka na ntango kotika fungola mpe akeyi'],
#  ['kompani omonaki ya kotongela biso kompani ya kindumba'],
#  ['akoma na ye kaka mɔtɔ mabanga'],
#  ['ecelence asilisi kolia fufu na ngai ngai ya mosaka na nyamazamba'],
#  ['yɔ na ngai lisolo ezalaka lisusu te'],
#  ['alingaka kotala baemission ya francais te'],
#  ['nazwa momeseno ya koyokaka makelele ya koleka na yɔ'],
#  ['ebakata na villa'],
#  ['ameli soi'],
#  ['kasi barombu basakanaka na yango te'],
#  ['ayebi que soki afandisi masolo na barumbute na parti na bango asambowa'],
#  ['na telema na yamba yɔ'],
#  ['pe etekamaki'],
#  ['atali esika motuka etelemaki'],
#  ['atali ndako basepeli na ngoma kasi'],
#  ['bana na yɔ bazalaka lisusu na ngai te'],
#  ['na minuti mokε motuka etikali se mabende'],
#  ['kombo na yango ezalaki babeti ya kin'],
#  ['yɔ okolobela ngai nini'],
#  ['makambo nini zoloba'],
#  ['oyebi te quebanda kala liboso kutu mindεlε baya baluba bazalaki kokεndε koteka bilɔkɔ epayi ya bakongo pe bakongo bazalaki kokεndε koteka bilɔkɔ na kasai'],
#  ['na bapanzi ya sango na bato bango bayambaka balobaka makambo ezanga mɔtɔ na makolo'],
#  ['bato mosusu pe bakoma koya koluka ye wana po asalisa bango na bapasi na bango'],
#  ['otanga na ecole nini'],
#  ['soki okoti na lopango lokola nde bamemi yɔ na ndɔtɔ na myamibitche na amerika'],
#  ['mwa mayi moko ezalaki wana'],
#  ['yo okanisi to ye biote'],
#  ['yɔ pe ozalaka mwana ya bago mbo'],
#  ['ayebi pe malamu ti na nini azali kobenga ye'],
#  ['avandi mwa kimia azongisi mokongo na nsima'],
#  ['bakutani pe na bandeko misusu ya kilo lokola bango'],
#  ['kuta mokolo wana tshotsho alobaka lisusu te likambo ya barumbou'],
#  ['mokonzi nzela oyɔ azalaki kolanda ezalaki malamu te'],
#  ['nazobenga nani'],
#  ['osombi quatre fa quatre ya gaya ozodondela biso na avenu bokasa oyɔ bokomisa liziba'],
#  ['suka suka akoya kofanda awa libela'],
#  ['bokasatala ndenge ekoma'],
#  ['bakozwa yɔ na kilo temps'],
#  ['azalaki na mapango tuku mibale'],
#  ['soki olandie elimboli ya bakɔkɔ nzambe atia mibeko oyɔ etambusaka mokili'],
#  ['obosani ete azali na katickati ya fulu ya kinshasa'],
#  ['avandi mwa kimya'],
#  ['excelence amilobi ndenge ezali'],
#  ['tshotshoko diongo apusani mpεmbεni na bango'],
#  ['abandi masolo politiki ndenge azoka na kobongisa bato mbo soki baponi ye'],
#  ['malεmbε malεmbε bato bazalaki koleka na balabala bayoki makelele'],
#  ['makambo to milukelaka'],
#  ['ekipi yango ezalaki kosangisa bana ya zone ya kinshasa pe zone ya barumbou'],
#  ['baluka bavilla bazwa bavilla'],
#  ['ekomi na ngonga moko boye ekomi kosenga kosala maponomi'],
#  ['mbele ezali kongala'],
#  ['oyɔ ya kobela opesi mbɔngɔ ya lopitalo oy ya mbɔngɔ ya kelasi pesi oyɔ bazali na nzala opesi'],
#  ['bango nyɔnso bazalaka lingomba moko ya politique ezalaki lingomba ya mokonzi ya mboka'],
#  ['azalaka na ye mpe na baninga te to bandeko oyɔ bayaka kotala ye'],
#  ['lokuta na lofundu batata na bamama mibimba'],
#  ['tata oyɔ ya pawoa soki kaka vide emonani amamolipawu'],
#  ['na nsima ya sanza misato mwananyoka mamwoare ezosala kaka eyemba mopao mokonzi'],
#  ['napesa yɔ mbote molimo esemi na suki awa'],
#  ['akangisa komisionnair kasi commisionnaire ayebi te nini akoyebisa moginque'],
#  ['totioko diongo amilobeli na se ya motema nayebaka te nini etinda ngai naloba que nawuta barumbo'],
#  ['makambo ya koboma na ezalaki te'],
#  ['azalaki koloba azalaki kopusana pelεpεnε ya motuka yango'],
#  ['kaka mongongo apεpe kala ezoganga la bafla osilisi banganda ya pario'],
#  ['sikoyɔ na kongo tozali na elɔkɔ ya mwana na mwana azwa partie na ye abendana'],
#  ['bokutani po mokonzi na mokonzi ya zolua kwanga mpo na mboka na ye'],
#  ['mwa mbɔngɔ ya bapolo mwandaki ekosopa mabele na aveni bokasa djalεlo ekoyembama ete azali nsoso ya mboka'],
#  ['bafinga ye na mpo asa'],
#  ['shotshokodiongoye wana akoti na mikala moko na barumbu ezalaki na esika balabalaka sali ekatana na kiteka'],
#  ['mwasi oyɔ bazalaki kobenga atelemi'],
#  ['tshotshokadiongo motoki ya mpio ebandi kotanga'],
#  ['muji ameseni mpe na ndako ya mbεlε na mbala moko'],
#  ['opotani na kabila kuna to mopanzi mbala moko ko be mɔtɔ oposition'],
#  ['ezalaki na bamibo dineuf cent qatrevant na ntango ya mobutu'],
#  ['okoexpliquer ngai nini'],
#  ['soki kaka polele pawu'],
#  ['akeyi kozinda kuna'],
#  ['pondelu oyɔ mwana nyoka abongisaki ndako wana aza na likanisi te'],
#  ['tshotsokodionga kamoniaboapo'],
#  ['boki nasombi ezali kaka lousitu bino bozali na vieux na ngai bosimbi masolo'],
#  ['nazali elonga ngai muji mwana ya vieux car'],
#  ['mayεlε te na wangana'],
#  ['botingaamεliki bokonzi po bokota boloko te'],
#  ['villa ya dolar kotokama misato'],
#  ['smartefone oyɔ bana goma na bukavu bakokoka kosomba te'],
#  ['akobi na koloba ete soki bobwakisi ngai kotiya nani'],
#  ['kozonga azozonga na kolemba wana nyɔnso makanisi kaka aya kopemisa milimo na tolo ya moki'],
#  ['yɔ na mwasi na yɔ nabanla na yɔ bolie yango'],
#  ['akuti lopango polele bato bazali kokomba kokata matiti kosukola ndako'],
#  ['ata kokombo ya kokoma bozoyi batimbɔngɔ nkombo'],
#  ['esengi kaka yɔ otiya libaya kuna'],
#  ['bomɔtɔ na bango balongolaki'],
#  ['bamomi to bakomaki bamomi na yɔ'],
#  ['na ntango wana komune bazalaki kobenga yango zone'],
#  ['yɔ obosani que biso mutu to banda masolo ya bavilla'],
#  ['ayebi mongongo wana malamu'],
#  ['esengi kaka ndenge nde kcolaiserra lobaka benda molayi tii bakolεmba'],
#  ['bana ya tour bazangi bamama basi ya beno bazangi mibali mibali ya kasa bazangi basi'],
#  ['kimoninga tango bokonzi bakonzi ezalaka te'],
#  ['toloba nine'],
#  ['soki etangama okokufa na pepo ata osali ndenge nini suka suka okomata kaka na pepo'],
#  ['motuka moko ya moindo bitala tala ya molili'],
#  ['tshostshokodiongo ayoki neti pepe kale abimi na nkunda mpe azali kozomela ye'],
#  ['na libanda banzela ezali kaka ya kokufa'],
#  ['bilini ya bomoi na ye etamboli liboso na ye lokola defile na trienfale'],
#  ['zela nanu'],
#  ['mwananyoka apusani pene na ye azwi kopo ya masanga amεlisi excellence'],
#  ['tshotsho ayanoli na se ya motema ebongonaki kwiti soki balabala ezali te ekosala nini'],
#  ['bana basili nakokufa ngai matoyi lokola ezosala te'],
#  ['na luki butu na moyi babenganga excellence ye oyɔ aleki na malonga'],
#  ['na wele bokonzi na kisasa nazwi ntango te ya kobatela yɔ'],
#  ['bato mitano balali bibembe'],
#  ['bana oyɔ obomaki bazalaki lokola bana na ngai'],
#  ['balabala mobimba ebukanaki na milolo ya koolola yɔ'],
#  ['pavetete lokola mwamedali gorge formene dem s bon bango nyɔnso baleka na balabala bokasar'],
#  ['abongisa ndako na bango kasi azonga te']]

# %%
def map_to_pred(batch):
    with torch.no_grad():
      input_values = torch.tensor(batch["input_values"]).unsqueeze(0)
      logits = model(input_values).logits
    #pred_ids = torch.argmax(logits, dim=-1)
    #batch["pred_str"] = processor.batch_decode(pred_ids)[0]
    batch["pred_str"]=processor.batch_decode(logits.numpy()).text[0]
    batch["text"] = processor1.decode(batch["labels"], group_tokens=False)
    return batch

# %%
def map_to_pred(batch):
    with torch.no_grad():
      input_values = torch.tensor(batch["input_values"]).unsqueeze(0)
      logits = model(input_values).logits
    #pred_ids = torch.argmax(logits, dim=-1)
    #batch["pred_str"] = processor.batch_decode(pred_ids)[0]
    batch["pred_str"]=processor.batch_decode(logits.numpy()).text[0]
    batch["text"] = processor.decode(batch["labels"], group_tokens=False)
    return batch

# %%
result = lingala_test.map(map_to_pred, remove_columns=lingala_test.column_names)
# Out:
#   0%|          | 0/180 [00:00<?, ?ex/s]

# %%
result
# Out:
# Dataset({
#     features: ['pred_str', 'text'],
#     num_rows: 180
# })

# %%
show_random_elements(result)
# Out:
# 180
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pred_str</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>makambo nini zoloba</td>
#       <td>makambo nini ozoloba</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nazwa momeseno ya koyokaka makelele ya koleka na yɔ</td>
#       <td>nazwa momeseno ya koyokaka makelele ya kolelaka na yɔ</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>baye komona ete azalaki kolobela mopa oyɔ azalaki na katiya masedesi ya mwindu</td>
#       <td>bayei komona ete azalaki kolobela mopao oyɔ azalaki na kati ya mercedes ya mwindu</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>soki okoti na lopango lokola nde bamemi yɔ na ndɔtɔ na myamibitche na amerika</td>
#       <td>soki okoti na kati ya lopango lokola nde bamemi yɔ na ndɔtɔ na miami beach na amerika</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>soki etangama okokufa na pepo ata osali ndenge nini suka suka okomata kaka na pepo</td>
#       <td>soki etangama okokufa na pepo ata osali ndenge nini sukasuka okomata kaka na pepo</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>mwa mbɔngɔ ya bapolo mwandaki ekosopa mabele na aveni bokasa djalεlo ekoyembama ete azali nsoso ya mboka</td>
#       <td>mwa mbɔngɔ ya  bapolo mwa danki ekosopa mabele na avenue bokasa djalεlɔ ekoyembama ete azali nsoso ya mboka</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>bakozwa yɔ na kilo temps</td>
#       <td>bakozwa yɔ na kilo tein</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>na luki butu na moyi babenganga excellence ye oyɔ aleki na malonga</td>
#       <td>naluki butu na moyi babenga ngai excellence ye oyɔ aleki na malonga</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ezalaki na bamibo dineuf cent qatrevant na ntango ya mobutu</td>
#       <td>ezalaki na bamibu diznef cent katre vin na tango ya mobutu</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>mingala mike mike pe epayi basi oyɔ ya mpεmbεni bango basengaka na ndenge ya mokε te</td>
#       <td>mingala mike mike pe epayi basi oyɔ ya mpεmbεni bango basengaka na ndenge ya muke te</td>
#     </tr>
#   </tbody>
# </table>

# %%
from datasets import load_dataset, load_metric

# %%
#def compute_metrics(pred):
#    pred_logits = pred.predictions
#    pred_ids = np.argmax(pred_logits, axis=-1)
#
#    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id
#
#    pred_str = processor.batch_decode(pred_logits.numpy())
    # we do not want to group tokens when computing the metrics
#    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

#    wer = wer_metric.compute(predictions=pred_str, references=label_str)

#    return {"wer": wer}

# %%
from jiwer import wer

# %%
print("Test WER: {:.3f}".format(wer(result["pred_str"], result["text"])))
# Out:
# Test WER: 0.239
