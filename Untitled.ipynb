# %%
cd dataset/ling_fleurs/
# Out:
# /home/ubuntu/CdWav2Vec/dataset/ling_fleurs

# %%
# !wget https://huggingface.co/datasets/google/fleurs/resolve/main/data/ln_cd/audio/train.tar.gz
# Out:
# --2023-08-11 11:34:42--  https://huggingface.co/datasets/google/fleurs/resolve/main/data/ln_cd/audio/train.tar.gz
# Resolving huggingface.co (huggingface.co)... 99.84.108.70, 99.84.108.87, 99.84.108.129, ...
# Connecting to huggingface.co (huggingface.co)|99.84.108.70|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://huggingface.co/datasets/google/fleurs/resolve/main/data/ln_cd/audio/test.tar.gz
# Out:
# --2023-08-11 11:35:49--  https://huggingface.co/datasets/google/fleurs/resolve/main/data/ln_cd/audio/test.tar.gz
# Resolving huggingface.co (huggingface.co)... 99.84.108.87, 99.84.108.129, 99.84.108.55, ...
# Connecting to huggingface.co (huggingface.co)|99.84.108.87|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://huggingface.co/datasets/google/fleurs/resolve/main/data/ln_cd/audio/dev.tar.gz
# Out:
# --2023-08-11 11:36:02--  https://huggingface.co/datasets/google/fleurs/resolve/main/data/ln_cd/audio/dev.tar.gz
# Resolving huggingface.co (huggingface.co)... 99.84.108.70, 99.84.108.55, 99.84.108.129, ...
# Connecting to huggingface.co (huggingface.co)|99.84.108.70|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://huggingface.co/datasets/google/fleurs/blob/main/data/ln_cd/dev.tsv
# Out:
# --2023-08-11 11:36:54--  https://huggingface.co/datasets/google/fleurs/blob/main/data/ln_cd/dev.tsv
# Resolving huggingface.co (huggingface.co)... 99.84.108.55, 99.84.108.70, 99.84.108.87, ...
# Connecting to huggingface.co (huggingface.co)|99.84.108.55|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 731992 (715K) [text/html]
# Saving to: ‘dev.tsv’
#
# dev.tsv             100%[===================>] 714.84K  --.-KB/s    in 0.01s
#
# 2023-08-11 11:36:54 (54.1 MB/s) - ‘dev.tsv’ saved [731992/731992]

# %%
# !wget https://huggingface.co/datasets/google/fleurs/blob/main/data/ln_cd/test.tsv
# Out:
# --2023-08-11 11:37:13--  https://huggingface.co/datasets/google/fleurs/blob/main/data/ln_cd/test.tsv
# Resolving huggingface.co (huggingface.co)... 99.84.108.129, 99.84.108.87, 99.84.108.70, ...
# Connecting to huggingface.co (huggingface.co)|99.84.108.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73179 (71K) [text/html]
# Saving to: ‘test.tsv’
#
# test.tsv            100%[===================>]  71.46K  --.-KB/s    in 0.001s
#
# 2023-08-11 11:37:13 (61.1 MB/s) - ‘test.tsv’ saved [73179/73179]

# %%
# !wget https://huggingface.co/datasets/google/fleurs/blob/main/data/ln_cd/train.tsv
# Out:
# --2023-08-11 11:37:39--  https://huggingface.co/datasets/google/fleurs/blob/main/data/ln_cd/train.tsv
# Resolving huggingface.co (huggingface.co)... 99.84.108.129, 99.84.108.87, 99.84.108.70, ...
# Connecting to huggingface.co (huggingface.co)|99.84.108.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73192 (71K) [text/html]
# Saving to: ‘train.tsv’
#
# train.tsv           100%[===================>]  71.48K  --.-KB/s    in 0.001s
#
# 2023-08-11 11:37:39 (95.4 MB/s) - ‘train.tsv’ saved [73192/73192]

# %%
# !tar -xvzf train.tar.gz
# Out:
# train/
# train/10003306233985436987.wav
# train/10012405356243256885.wav
# train/10020170435596488786.wav
# train/10022402884365403868.wav
# train/10024445911495816116.wav
# train/10032696154624834623.wav
# train/10036785670352892421.wav
# train/100382331724864921.wav
# train/100526485150669790.wav
# train/1005801236924150746.wav
# train/10059782727484999679.wav
# train/10063163442003371134.wav
# train/10079574271898285573.wav
# train/10080358577593395790.wav
# train/10087606842755774096.wav
# train/1009038064398077354.wav
# train/10109152233883212557.wav
# train/10112829285091790944.wav
# train/10120979883180500944.wav
# train/10125744042764024807.wav
# train/1013092087449529615.wav
# train/10132551835212946549.wav
# train/1014399895671202759.wav
# train/10144563415314755665.wav
# train/10152300587023211316.wav
# train/1015401532384506425.wav
# train/10158009457165673631.wav
# train/1016903214733516283.wav
# train/1017833860145720856.wav
# train/1018773048171331663.wav
# ...

# %%
# !tar -xvzf test.tar.gz
# Out:
# test/
# test/10036744541001463313.wav
# test/10050948239377258563.wav
# test/1006532362706302916.wav
# test/10087419690345263317.wav
# test/10114035190060742208.wav
# test/10141748099555799895.wav
# test/10225404183906226405.wav
# test/10269460410134493950.wav
# test/10346237830211664938.wav
# test/10394942906745920050.wav
# test/10414952640576673500.wav
# test/10422753584725408262.wav
# test/10436808485151319474.wav
# test/10493005560152608064.wav
# test/10502924004856584983.wav
# test/10548294969843710483.wav
# test/10591424178548675174.wav
# test/10606250733355058852.wav
# test/10744588742844257287.wav
# test/10757729126705763084.wav
# test/10767529256191095803.wav
# test/10781705453164678922.wav
# test/10790538854975929142.wav
# test/10903439444730299648.wav
# test/1091878051741900596.wav
# test/10969618969375995422.wav
# test/1102050623944210180.wav
# test/11022380965177095340.wav
# test/11054704652012446709.wav
# test/110571078413942726.wav
# test/11119321701686080243.wav
# ...

# %%
# !tar -xvzf dev.tar.gz
# Out:
# dev/
# dev/10016733824831284541.wav
# dev/10075547217854967812.wav
# dev/10096953997051921855.wav
# dev/10165840911153414459.wav
# dev/10211868553605125727.wav
# dev/10422021560344309175.wav
# dev/10430766143693951018.wav
# dev/10510152275479538272.wav
# dev/10539205566472084729.wav
# dev/10607313779946938290.wav
# dev/10735644079400440552.wav
# dev/10804124163158836878.wav
# dev/10957514908680246674.wav
# dev/11133993490590966703.wav
# dev/11175739013414965170.wav
# dev/1120632829311929178.wav
# dev/11234229510407868607.wav
# dev/11316944742945277792.wav
# dev/11425024460884553764.wav
# dev/11583358679164358044.wav
# dev/11726130877482275416.wav
# dev/11876961447285569368.wav
# dev/12066108266135104247.wav
# dev/12083428210859120190.wav
# dev/12089228403278762737.wav
# dev/12098727373704997346.wav
# dev/12100614340205109687.wav
# dev/12131727746151629521.wav
# dev/12176920519952787388.wav
# dev/12180281703596068649.wav
# dev/1222070722468031145.wav
# dev/12242278207625064637.wav
# ...

# %%
input_file_path = "test.txt"
output_file_path = "output.txt"

with open(input_file_path, "r") as input_file, open(output_file_path, "w") as output_file:
    for line in input_file:
        parts = line.strip().split('\t')
        wav_file = parts[0]
        transcription = ' '.join(parts[1:])  # Join the transcription parts back together
        transcription = transcription.rstrip()  # Remove trailing white spaces
        formatted_line = f"{wav_file} {transcription}\n"
        output_file.write(formatted_line)

# %%
input_file_path = "train.txt"
output_file_path = "output.txt"

with open(input_file_path, "r") as input_file, open(output_file_path, "w") as output_file:
    for line in input_file:
        parts = line.strip().split('\t')
        wav_file = parts[0]
        transcription = ' '.join(parts[1:])  # Join the transcription parts back together
        transcription = transcription.rstrip()  # Remove trailing white spaces
        formatted_line = f"{wav_file} {transcription}\n"
        output_file.write(formatted_line)

# %%
cd
# Out:
# /home/ubuntu

# %%
cd CdWav2Vec/data_prep_scripts/ft_scripts/
# Out:
# /home/ubuntu/CdWav2Vec/data_prep_scripts/ft_scripts

# %%
ls
# Out:
# m_prep_script.py*  m_process.sh*  normalize_sr.sh*  readme.md*

# %%
# !bash m_process.sh /home/ubuntu/CdWav2Vec/dataset/
